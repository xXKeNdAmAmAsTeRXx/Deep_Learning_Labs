# %% [markdown]
# # Getting Data and network params

# %%
import os
import pandas as pd
from torch.utils.data import Subset
from sklearn.model_selection import train_test_split
from utils8 import AudioCNN
from utils8.data import AudioDataset, get_dataloader

# Get Data
path = os.path.join('Data', 'Digits')
classes = ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']
dataset = AudioDataset(path, classes)

# Data Split and Subsets
idx = list(range(len(dataset)))
labels = dataset.labels
train_val_idx, test_idx = train_test_split(idx, test_size=0.2, stratify=labels, random_state=42)

train_val_set = Subset(dataset, train_val_idx)
test_set = Subset(dataset, test_idx)


studies = sorted(os.listdir('optuna_results'))

print('Available studies: ')
for s in studies:
    s = s.replace('(', '_')
    s = s.replace(')', '_')
    parsed_s = s.split('_')
    print(f'{parsed_s[1]}/{parsed_s[2]}/{parsed_s[3]} - {parsed_s[4]}')

last_study_path = os.path.join('optuna_results', studies[-1])
last_study = pd.read_csv(last_study_path)


last_study
# Out:
# Available studies:
# 20/05/2026 - 12:08
#     number         value              datetime_start  \
# 0       20      0.500792  2026-05-20 07:27:05.804786
# 1       21      0.514238  2026-05-20 08:21:50.846912
# 2       24      0.551658  2026-05-20 11:07:16.834302
# 3       16      0.648541  2026-05-20 03:45:57.568698
# 4       10      0.704174  2026-05-19 21:23:32.511006
# 5       19      0.708246  2026-05-20 06:31:32.789569
# 6       17      0.758230  2026-05-20 04:41:27.958938
# 7       11      0.832159  2026-05-19 22:22:24.763269
# 8       22      0.853123  2026-05-20 09:16:40.121755
# 9        7      1.004616  2026-05-19 18:20:56.262730
# 10       4      1.013875  2026-05-19 15:14:45.405295
# 11       0      1.196936  2026-05-19 11:00:47.016047
# 12      13      1.314308  2026-05-20 00:55:01.898122
# 13       8      1.397011  2026-05-19 19:28:02.653087
# 14       5      1.510237  2026-05-19 16:17:23.707967
# 15       6      1.531632  2026-05-19 17:18:02.549915
# 16       2      1.625957  2026-05-19 13:13:08.138388
# 17      18      1.844088  2026-05-20 05:36:38.281274
# 18      12      2.025014  2026-05-19 23:51:49.981899
# 19      23      2.087915  2026-05-20 10:11:43.975265
# 20      14      2.302857  2026-05-20 01:51:52.371810
# 21      15      2.303453  2026-05-20 02:46:43.355018
# 22       3      2.384819  2026-05-19 14:13:11.344020
# 23       1      2.549511  2026-05-19 12:06:40.491184
# 24       9  27348.432048  2026-05-19 20:25:28.040596
#
#              datetime_complete                duration  params_dropout_rate  \
# 0   2026-05-20 08:21:50.843694  0 days 00:54:45.038908             0.008297
# 1   2026-05-20 09:16:40.114468  0 days 00:54:49.267556             0.010482
# 2   2026-05-20 12:08:31.918352  0 days 01:01:15.084050             0.014147
# 3   2026-05-20 04:41:27.957551  0 days 00:55:30.388853             0.004735
# 4   2026-05-19 22:22:24.762476  0 days 00:58:52.251470             0.395976
# 5   2026-05-20 07:27:05.804116  0 days 00:55:33.014547             0.001090
# 6   2026-05-20 05:36:38.277407  0 days 00:55:10.318469             0.002047
# 7   2026-05-19 23:51:49.931434  0 days 01:29:25.168165             0.433315
# 8   2026-05-20 10:11:43.974543  0 days 00:55:03.852788             0.009083
# 9   2026-05-19 19:28:02.652269  0 days 01:07:06.389539             0.228612
# 10  2026-05-19 16:17:23.706852  0 days 01:02:38.301557             0.000027
# 11  2026-05-19 12:06:40.489545  0 days 01:05:53.473498             0.000203
# 12  2026-05-20 01:51:52.370772  0 days 00:56:50.472650             0.051323
# 13  2026-05-19 20:25:28.039919  0 days 00:57:25.386832             0.000060
# 14  2026-05-19 17:18:02.549095  0 days 01:00:38.841128             0.000274
# 15  2026-05-19 18:20:56.262000  0 days 01:02:53.712085             0.000142
# 16  2026-05-19 14:13:11.343272  0 days 01:00:03.204884             0.000022
# 17  2026-05-20 06:31:32.788881  0 days 00:54:54.507607             0.004962
# 18  2026-05-20 00:55:01.896740  0 days 01:03:11.914841             0.477720
# 19  2026-05-20 11:07:16.829905  0 days 00:55:32.854640             0.000832
# 20  2026-05-20 02:46:43.354296  0 days 00:54:50.982486             0.003122
# 21  2026-05-20 03:45:57.568006  0 days 00:59:14.212988             0.102244
# 22  2026-05-19 15:14:45.404528  0 days 01:01:34.060508             0.023128
# 23  2026-05-19 13:13:08.137683  0 days 01:06:27.646499             0.023834
# 24  2026-05-19 21:23:32.510279  0 days 00:58:04.469683             0.000289
#
#     params_lr  params_patience  params_weight_decay     state
# 0    0.001607                5             0.000143  COMPLETE
# 1    0.001545                5             0.000138  COMPLETE
# 2    0.001752                5             0.000037  COMPLETE
# 3    0.000451                3             0.000044  COMPLETE
# 4    0.001647                2             0.000012  COMPLETE
# 5    0.000297                3             0.000029  COMPLETE
# 6    0.000220                3             0.000058  COMPLETE
# 7    0.000828                2             0.000016  COMPLETE
# 8    0.000138                5             0.000135  COMPLETE
# 9    0.000280                2             0.001309  COMPLETE
# 10   0.000090                6             0.000467  COMPLETE
# 11   0.000904                4             0.002246  COMPLETE
# 12   0.003452               10             0.000014  COMPLETE
# 13   0.000030                7             0.000185  COMPLETE
# 14   0.000025                7             0.000339  COMPLETE
# 15   0.000048                2             0.004319  COMPLETE
# 16   0.000017                8             0.000517  COMPLETE
# 17   0.007742                5             0.000055  COMPLETE
# 18   0.003704                4             0.000010  COMPLETE
# 19   0.013048                5             0.000138  COMPLETE
# 20   0.000697                4             0.094684  COMPLETE
# 21   0.012615                3             0.000064  COMPLETE
# 22   0.043776                8             0.007401  COMPLETE
# 23   0.042521                6             0.001694  COMPLETE
# 24   0.356128                8             0.008582  COMPLETE

# %%
study = last_study.iloc[0].to_dict()

network_col = ["params_dropout_rate", "params_lr", "params_patience", "params_weight_decay"]
best_params = {}
for col in network_col:
    best_params[col.removeprefix('params_')] = study[col]

best_params
# Out:
# {'dropout_rate': 0.0082966517228649,
#  'lr': 0.0016068082173041,
#  'patience': 5,
#  'weight_decay': 0.0001426599145501}

# %% [markdown]
# # Training for different datasets

# %%
import os
from sklearn.model_selection import KFold
from torch import nn,optim
from utils8.dir_managment import clean_dir
from utils8.AudioCNN import AudioCNN
from utils8.training import train_one_fold, get_train_loaders, save_model_dict, save_target_labels



for amount in [0.2, 0.4, 0.6, 0.8]:
    model_name = f'model_{amount*100}%'
    save_model_dir = os.path.join('Models','Task_4', model_name)
    clean_dir(save_model_dir)
    os.makedirs(save_model_dir, exist_ok=True)

    model_params = {'dropout_rate': best_params['dropout_rate'], 'num_classes': 10}
    save_model_dict(model_params, save_model_dir)
    save_target_labels(classes, save_model_dir)

    # Data
    labels = [dataset.labels[i] for i in train_val_idx]
    _, smaller_set_idx = train_test_split(train_val_idx, test_size=amount, stratify=labels, random_state=42)
    smaller_set = Subset(dataset, smaller_set_idx)

    N_EPOCHS = 30   # Train for 30 epochs as best val loss is always hit 20-30 epoch
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    for fold, (train_idx, val_idx) in enumerate(kf.split(smaller_set)):
        print(f'\n ===================== Training Fold {fold}  ===================== \n')
        # Loaders
        train_loader, val_loader = get_train_loaders(smaller_set, train_idx,val_idx , batch_size=32)

        # Model, Optimizer, Criterion
        criterion = nn.CrossEntropyLoss()
        model =  AudioCNN(dropout_rate=best_params['dropout_rate'])
        optimizer = optim.Adam(model.parameters(), lr=best_params['lr'], weight_decay=best_params['weight_decay'])
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=best_params['patience'])

        # Fold Training
        loss = train_one_fold(fold, model, train_loader, val_loader, optimizer, scheduler, criterion, n_epochs=N_EPOCHS, write_model_dir=save_model_dir, writer=None)
# Out:
# Cleaning existing files at Models/Task_4/model_20.0%...
# Model dict saved in Models/Task_4/model_20.0%/model_dict.json
# Labels dict saved in Models/Task_4/model_20.0%/data_labels.json
#
#  ===================== Training Fold 0  =====================
#
# Saved new best model to Models/Task_4/model_20.0%/fold_0.pth, with new best_val_loss=2.2255956693129106
# Saved new best model to Models/Task_4/model_20.0%/fold_0.pth, with new best_val_loss=1.8081590316512368
# Saved new best model to Models/Task_4/model_20.0%/fold_0.pth, with new best_val_loss=1.4987735585732893
# Saved new best model to Models/Task_4/model_20.0%/fold_0.pth, with new best_val_loss=1.3795562792908063
# Saved new best model to Models/Task_4/model_20.0%/fold_0.pth, with new best_val_loss=1.2137839848344976
# Saved new best model to Models/Task_4/model_20.0%/fold_0.pth, with new best_val_loss=1.1241936819119887
# Saved new best model to Models/Task_4/model_20.0%/fold_0.pth, with new best_val_loss=1.0624723624099384
# Saved new best model to Models/Task_4/model_20.0%/fold_0.pth, with new best_val_loss=0.972750639373606
# Saved new best model to Models/Task_4/model_20.0%/fold_0.pth, with new best_val_loss=0.8806459118019451
# Saved new best model to Models/Task_4/model_20.0%/fold_0.pth, with new best_val_loss=0.8297870484265414
# Saved new best model to Models/Task_4/model_20.0%/fold_0.pth, with new best_val_loss=0.8239239698106592
# Saved new best model to Models/Task_4/model_20.0%/fold_0.pth, with new best_val_loss=0.7923291664231907
#
#  ===================== Training Fold 1  =====================
#
# Saved new best model to Models/Task_4/model_20.0%/fold_1.pth, with new best_val_loss=2.0997295054522427
# Saved new best model to Models/Task_4/model_20.0%/fold_1.pth, with new best_val_loss=1.9952162883498452
# Saved new best model to Models/Task_4/model_20.0%/fold_1.pth, with new best_val_loss=1.7673689777200872
# Saved new best model to Models/Task_4/model_20.0%/fold_1.pth, with new best_val_loss=1.5576728799126365
# Saved new best model to Models/Task_4/model_20.0%/fold_1.pth, with new best_val_loss=1.5522628318179736
# Saved new best model to Models/Task_4/model_20.0%/fold_1.pth, with new best_val_loss=1.4637299180030823
# Saved new best model to Models/Task_4/model_20.0%/fold_1.pth, with new best_val_loss=1.3668733483011073
# Saved new best model to Models/Task_4/model_20.0%/fold_1.pth, with new best_val_loss=1.127734829079021
# Saved new best model to Models/Task_4/model_20.0%/fold_1.pth, with new best_val_loss=1.0848320058800958
# Saved new best model to Models/Task_4/model_20.0%/fold_1.pth, with new best_val_loss=1.0507108189842918
# Saved new best model to Models/Task_4/model_20.0%/fold_1.pth, with new best_val_loss=0.9994635554877195
# Saved new best model to Models/Task_4/model_20.0%/fold_1.pth, with new best_val_loss=0.9715657559308138
# Saved new best model to Models/Task_4/model_20.0%/fold_1.pth, with new best_val_loss=0.8761769817634062
#
#  ===================== Training Fold 2  =====================
#
# Saved new best model to Models/Task_4/model_20.0%/fold_2.pth, with new best_val_loss=2.006700889630751
# Saved new best model to Models/Task_4/model_20.0%/fold_2.pth, with new best_val_loss=1.6253597086126155
# Saved new best model to Models/Task_4/model_20.0%/fold_2.pth, with new best_val_loss=1.593811815435236
# Saved new best model to Models/Task_4/model_20.0%/fold_2.pth, with new best_val_loss=1.3593317161906848
# Saved new best model to Models/Task_4/model_20.0%/fold_2.pth, with new best_val_loss=1.3370946537364612
# Saved new best model to Models/Task_4/model_20.0%/fold_2.pth, with new best_val_loss=1.084349510344592
# Saved new best model to Models/Task_4/model_20.0%/fold_2.pth, with new best_val_loss=1.0667241405357013
# Saved new best model to Models/Task_4/model_20.0%/fold_2.pth, with new best_val_loss=1.0330719378861515
# Saved new best model to Models/Task_4/model_20.0%/fold_2.pth, with new best_val_loss=1.0098513825373217
# Saved new best model to Models/Task_4/model_20.0%/fold_2.pth, with new best_val_loss=0.9846743426539681
# Saved new best model to Models/Task_4/model_20.0%/fold_2.pth, with new best_val_loss=0.9791090759364042
# Saved new best model to Models/Task_4/model_20.0%/fold_2.pth, with new best_val_loss=0.858314415270632
#
#  ===================== Training Fold 3  =====================
#
# Saved new best model to Models/Task_4/model_20.0%/fold_3.pth, with new best_val_loss=2.026998509060253
# Saved new best model to Models/Task_4/model_20.0%/fold_3.pth, with new best_val_loss=1.9197936816649004
# Saved new best model to Models/Task_4/model_20.0%/fold_3.pth, with new best_val_loss=1.711558764631098
# Saved new best model to Models/Task_4/model_20.0%/fold_3.pth, with new best_val_loss=1.5702030279419639
# Saved new best model to Models/Task_4/model_20.0%/fold_3.pth, with new best_val_loss=1.394366903738542
# Saved new best model to Models/Task_4/model_20.0%/fold_3.pth, with new best_val_loss=1.2459868734533137
# Saved new best model to Models/Task_4/model_20.0%/fold_3.pth, with new best_val_loss=1.0722894018346614
# Saved new best model to Models/Task_4/model_20.0%/fold_3.pth, with new best_val_loss=1.0237714485688643
# Saved new best model to Models/Task_4/model_20.0%/fold_3.pth, with new best_val_loss=0.9584235169670798
# Saved new best model to Models/Task_4/model_20.0%/fold_3.pth, with new best_val_loss=0.9231707128611478
# Saved new best model to Models/Task_4/model_20.0%/fold_3.pth, with new best_val_loss=0.8708137625997717
#
#  ===================== Training Fold 4  =====================
#
# Saved new best model to Models/Task_4/model_20.0%/fold_4.pth, with new best_val_loss=2.076177250255238
# Saved new best model to Models/Task_4/model_20.0%/fold_4.pth, with new best_val_loss=1.8260385935956782
# Saved new best model to Models/Task_4/model_20.0%/fold_4.pth, with new best_val_loss=1.7513601617379622
# Saved new best model to Models/Task_4/model_20.0%/fold_4.pth, with new best_val_loss=1.7187964916229248
# Saved new best model to Models/Task_4/model_20.0%/fold_4.pth, with new best_val_loss=1.6047246943820606
# Saved new best model to Models/Task_4/model_20.0%/fold_4.pth, with new best_val_loss=1.4636420607566833
# Saved new best model to Models/Task_4/model_20.0%/fold_4.pth, with new best_val_loss=1.3757064992731267
# Saved new best model to Models/Task_4/model_20.0%/fold_4.pth, with new best_val_loss=1.242772795937278
# Saved new best model to Models/Task_4/model_20.0%/fold_4.pth, with new best_val_loss=1.1206958293914795
# Saved new best model to Models/Task_4/model_20.0%/fold_4.pth, with new best_val_loss=1.0830416245894
# Saved new best model to Models/Task_4/model_20.0%/fold_4.pth, with new best_val_loss=1.048093711788004
# Saved new best model to Models/Task_4/model_20.0%/fold_4.pth, with new best_val_loss=1.0154718946326862
# Saved new best model to Models/Task_4/model_20.0%/fold_4.pth, with new best_val_loss=1.0092665133151142
# Saved new best model to Models/Task_4/model_20.0%/fold_4.pth, with new best_val_loss=0.9782951338724657
# Model dict saved in Models/Task_4/model_40.0%/model_dict.json
# Labels dict saved in Models/Task_4/model_40.0%/data_labels.json
#
#  ===================== Training Fold 0  =====================
#
# Saved new best model to Models/Task_4/model_40.0%/fold_0.pth, with new best_val_loss=2.3028380166400564
# Saved new best model to Models/Task_4/model_40.0%/fold_0.pth, with new best_val_loss=1.9677746133370833
# Saved new best model to Models/Task_4/model_40.0%/fold_0.pth, with new best_val_loss=1.5571121776645833
# Saved new best model to Models/Task_4/model_40.0%/fold_0.pth, with new best_val_loss=1.3355440957979723
# Saved new best model to Models/Task_4/model_40.0%/fold_0.pth, with new best_val_loss=1.0021623583002524
# Saved new best model to Models/Task_4/model_40.0%/fold_0.pth, with new best_val_loss=0.9313293532891707
# Saved new best model to Models/Task_4/model_40.0%/fold_0.pth, with new best_val_loss=0.8889727199619467
# Saved new best model to Models/Task_4/model_40.0%/fold_0.pth, with new best_val_loss=0.783868709071116
# Saved new best model to Models/Task_4/model_40.0%/fold_0.pth, with new best_val_loss=0.7607737894762646
# Saved new best model to Models/Task_4/model_40.0%/fold_0.pth, with new best_val_loss=0.752803005955436
# Saved new best model to Models/Task_4/model_40.0%/fold_0.pth, with new best_val_loss=0.663584397428415
#
#  ===================== Training Fold 1  =====================
#
# Saved new best model to Models/Task_4/model_40.0%/fold_1.pth, with new best_val_loss=1.8661367784846912
# Saved new best model to Models/Task_4/model_40.0%/fold_1.pth, with new best_val_loss=1.6527990048581904
# Saved new best model to Models/Task_4/model_40.0%/fold_1.pth, with new best_val_loss=1.5689014088023792
# Saved new best model to Models/Task_4/model_40.0%/fold_1.pth, with new best_val_loss=1.4879333566535602
# Saved new best model to Models/Task_4/model_40.0%/fold_1.pth, with new best_val_loss=1.2835393710569902
# Saved new best model to Models/Task_4/model_40.0%/fold_1.pth, with new best_val_loss=1.0767598707567563
# Saved new best model to Models/Task_4/model_40.0%/fold_1.pth, with new best_val_loss=0.9616865915330973
# Saved new best model to Models/Task_4/model_40.0%/fold_1.pth, with new best_val_loss=0.9550638510422274
# Saved new best model to Models/Task_4/model_40.0%/fold_1.pth, with new best_val_loss=0.8942433751442216
# Saved new best model to Models/Task_4/model_40.0%/fold_1.pth, with new best_val_loss=0.8794537633657455
# Saved new best model to Models/Task_4/model_40.0%/fold_1.pth, with new best_val_loss=0.8114280646497553
# Saved new best model to Models/Task_4/model_40.0%/fold_1.pth, with new best_val_loss=0.8036113760688088
#
#  ===================== Training Fold 2  =====================
#
# Saved new best model to Models/Task_4/model_40.0%/fold_2.pth, with new best_val_loss=1.873170484196056
# Saved new best model to Models/Task_4/model_40.0%/fold_2.pth, with new best_val_loss=1.5321513224731793
# Saved new best model to Models/Task_4/model_40.0%/fold_2.pth, with new best_val_loss=1.258544527671554
# Saved new best model to Models/Task_4/model_40.0%/fold_2.pth, with new best_val_loss=1.096892775459723
# Saved new best model to Models/Task_4/model_40.0%/fold_2.pth, with new best_val_loss=1.0754853026433424
# Saved new best model to Models/Task_4/model_40.0%/fold_2.pth, with new best_val_loss=0.9142508750612085
# Saved new best model to Models/Task_4/model_40.0%/fold_2.pth, with new best_val_loss=0.8766623003916307
# Saved new best model to Models/Task_4/model_40.0%/fold_2.pth, with new best_val_loss=0.7772101414474574
# Saved new best model to Models/Task_4/model_40.0%/fold_2.pth, with new best_val_loss=0.6889101043343544
#
#  ===================== Training Fold 3  =====================
#
# Saved new best model to Models/Task_4/model_40.0%/fold_3.pth, with new best_val_loss=1.7750263837250797
# Saved new best model to Models/Task_4/model_40.0%/fold_3.pth, with new best_val_loss=1.735145709731362
# Saved new best model to Models/Task_4/model_40.0%/fold_3.pth, with new best_val_loss=1.3792996298183093
# Saved new best model to Models/Task_4/model_40.0%/fold_3.pth, with new best_val_loss=1.252701539884914
# Saved new best model to Models/Task_4/model_40.0%/fold_3.pth, with new best_val_loss=1.1045165657997131
# Saved new best model to Models/Task_4/model_40.0%/fold_3.pth, with new best_val_loss=0.982210717417977
# Saved new best model to Models/Task_4/model_40.0%/fold_3.pth, with new best_val_loss=0.8726789504289627
# Saved new best model to Models/Task_4/model_40.0%/fold_3.pth, with new best_val_loss=0.8552684878761118
# Saved new best model to Models/Task_4/model_40.0%/fold_3.pth, with new best_val_loss=0.7534707229245793
# Saved new best model to Models/Task_4/model_40.0%/fold_3.pth, with new best_val_loss=0.6793832182884216
# Saved new best model to Models/Task_4/model_40.0%/fold_3.pth, with new best_val_loss=0.5791020034389063
# Saved new best model to Models/Task_4/model_40.0%/fold_3.pth, with new best_val_loss=0.5373059446838769
# Saved new best model to Models/Task_4/model_40.0%/fold_3.pth, with new best_val_loss=0.5340095904063095
# Saved new best model to Models/Task_4/model_40.0%/fold_3.pth, with new best_val_loss=0.47594118456948886
#
#  ===================== Training Fold 4  =====================
#
# Saved new best model to Models/Task_4/model_40.0%/fold_4.pth, with new best_val_loss=2.044385850429535
# Saved new best model to Models/Task_4/model_40.0%/fold_4.pth, with new best_val_loss=1.5669295191764832
# Saved new best model to Models/Task_4/model_40.0%/fold_4.pth, with new best_val_loss=1.4202083538879047
# Saved new best model to Models/Task_4/model_40.0%/fold_4.pth, with new best_val_loss=1.1075651442462748
# Saved new best model to Models/Task_4/model_40.0%/fold_4.pth, with new best_val_loss=0.9961977926167574
# Saved new best model to Models/Task_4/model_40.0%/fold_4.pth, with new best_val_loss=0.9207696630196138
# Saved new best model to Models/Task_4/model_40.0%/fold_4.pth, with new best_val_loss=0.8711539046330885
# Saved new best model to Models/Task_4/model_40.0%/fold_4.pth, with new best_val_loss=0.7743177833882245
# Saved new best model to Models/Task_4/model_40.0%/fold_4.pth, with new best_val_loss=0.7587406465953047
# Saved new best model to Models/Task_4/model_40.0%/fold_4.pth, with new best_val_loss=0.6922627579082142
# Saved new best model to Models/Task_4/model_40.0%/fold_4.pth, with new best_val_loss=0.6780385354703123
# Model dict saved in Models/Task_4/model_60.0%/model_dict.json
# Labels dict saved in Models/Task_4/model_60.0%/data_labels.json
#
#  ===================== Training Fold 0  =====================
#
# Saved new best model to Models/Task_4/model_60.0%/fold_0.pth, with new best_val_loss=1.582863371188824
# Saved new best model to Models/Task_4/model_60.0%/fold_0.pth, with new best_val_loss=1.1278714757699233
# Saved new best model to Models/Task_4/model_60.0%/fold_0.pth, with new best_val_loss=0.903816663301908
# Saved new best model to Models/Task_4/model_60.0%/fold_0.pth, with new best_val_loss=0.7958005089026231
# Saved new best model to Models/Task_4/model_60.0%/fold_0.pth, with new best_val_loss=0.7873020162949196
# Saved new best model to Models/Task_4/model_60.0%/fold_0.pth, with new best_val_loss=0.7853527137866387
# Saved new best model to Models/Task_4/model_60.0%/fold_0.pth, with new best_val_loss=0.7193804649206308
# Saved new best model to Models/Task_4/model_60.0%/fold_0.pth, with new best_val_loss=0.6634772763802455
# Saved new best model to Models/Task_4/model_60.0%/fold_0.pth, with new best_val_loss=0.6452345371246337
# Saved new best model to Models/Task_4/model_60.0%/fold_0.pth, with new best_val_loss=0.6205651216782057
# Saved new best model to Models/Task_4/model_60.0%/fold_0.pth, with new best_val_loss=0.6002612879643073
# Saved new best model to Models/Task_4/model_60.0%/fold_0.pth, with new best_val_loss=0.5945024631344356
# Saved new best model to Models/Task_4/model_60.0%/fold_0.pth, with new best_val_loss=0.5773589157141172
# Saved new best model to Models/Task_4/model_60.0%/fold_0.pth, with new best_val_loss=0.5542860684486536
# Saved new best model to Models/Task_4/model_60.0%/fold_0.pth, with new best_val_loss=0.5440918018038456
#
#  ===================== Training Fold 1  =====================
#
# Saved new best model to Models/Task_4/model_60.0%/fold_1.pth, with new best_val_loss=1.8165840295644906
# Saved new best model to Models/Task_4/model_60.0%/fold_1.pth, with new best_val_loss=1.5014141394541813
# Saved new best model to Models/Task_4/model_60.0%/fold_1.pth, with new best_val_loss=1.3034467678803665
# Saved new best model to Models/Task_4/model_60.0%/fold_1.pth, with new best_val_loss=1.0906735704495356
# Saved new best model to Models/Task_4/model_60.0%/fold_1.pth, with new best_val_loss=1.0006171556619496
# Saved new best model to Models/Task_4/model_60.0%/fold_1.pth, with new best_val_loss=0.8855089829518245
# Saved new best model to Models/Task_4/model_60.0%/fold_1.pth, with new best_val_loss=0.8244594257611495
# Saved new best model to Models/Task_4/model_60.0%/fold_1.pth, with new best_val_loss=0.7855342365228213
# Saved new best model to Models/Task_4/model_60.0%/fold_1.pth, with new best_val_loss=0.6254617250882663
# Saved new best model to Models/Task_4/model_60.0%/fold_1.pth, with new best_val_loss=0.6238579493302565
# Saved new best model to Models/Task_4/model_60.0%/fold_1.pth, with new best_val_loss=0.5622838336687822
# Saved new best model to Models/Task_4/model_60.0%/fold_1.pth, with new best_val_loss=0.5203048586845398
# Saved new best model to Models/Task_4/model_60.0%/fold_1.pth, with new best_val_loss=0.4971508210668197
# Saved new best model to Models/Task_4/model_60.0%/fold_1.pth, with new best_val_loss=0.484197568664184
#
#  ===================== Training Fold 2  =====================
#
# Saved new best model to Models/Task_4/model_60.0%/fold_2.pth, with new best_val_loss=1.6599184934909528
# Saved new best model to Models/Task_4/model_60.0%/fold_2.pth, with new best_val_loss=1.3729114844248844
# Saved new best model to Models/Task_4/model_60.0%/fold_2.pth, with new best_val_loss=1.1521340195949261
# Saved new best model to Models/Task_4/model_60.0%/fold_2.pth, with new best_val_loss=0.9280245047349196
# Saved new best model to Models/Task_4/model_60.0%/fold_2.pth, with new best_val_loss=0.8505477630175077
# Saved new best model to Models/Task_4/model_60.0%/fold_2.pth, with new best_val_loss=0.6953495392432579
# Saved new best model to Models/Task_4/model_60.0%/fold_2.pth, with new best_val_loss=0.6414847882894369
# Saved new best model to Models/Task_4/model_60.0%/fold_2.pth, with new best_val_loss=0.5652802077623514
# Saved new best model to Models/Task_4/model_60.0%/fold_2.pth, with new best_val_loss=0.5326589045616297
# Saved new best model to Models/Task_4/model_60.0%/fold_2.pth, with new best_val_loss=0.47068511981230515
#
#  ===================== Training Fold 3  =====================
#
# Saved new best model to Models/Task_4/model_60.0%/fold_3.pth, with new best_val_loss=1.8126958370208741
# Saved new best model to Models/Task_4/model_60.0%/fold_3.pth, with new best_val_loss=1.4495485562544603
# Saved new best model to Models/Task_4/model_60.0%/fold_3.pth, with new best_val_loss=1.2151019068864675
# Saved new best model to Models/Task_4/model_60.0%/fold_3.pth, with new best_val_loss=0.9592808888508724
# Saved new best model to Models/Task_4/model_60.0%/fold_3.pth, with new best_val_loss=0.8376337592418377
# Saved new best model to Models/Task_4/model_60.0%/fold_3.pth, with new best_val_loss=0.7533510391528789
# Saved new best model to Models/Task_4/model_60.0%/fold_3.pth, with new best_val_loss=0.6242899245940722
# Saved new best model to Models/Task_4/model_60.0%/fold_3.pth, with new best_val_loss=0.5804626267689925
# Saved new best model to Models/Task_4/model_60.0%/fold_3.pth, with new best_val_loss=0.539858787564131
# Saved new best model to Models/Task_4/model_60.0%/fold_3.pth, with new best_val_loss=0.5371185460915933
# Saved new best model to Models/Task_4/model_60.0%/fold_3.pth, with new best_val_loss=0.5312318897018066
# Saved new best model to Models/Task_4/model_60.0%/fold_3.pth, with new best_val_loss=0.5226385345825783
# Saved new best model to Models/Task_4/model_60.0%/fold_3.pth, with new best_val_loss=0.5172522664070129
# Saved new best model to Models/Task_4/model_60.0%/fold_3.pth, with new best_val_loss=0.5130014230425541
# Saved new best model to Models/Task_4/model_60.0%/fold_3.pth, with new best_val_loss=0.50020098227721
#
#  ===================== Training Fold 4  =====================
#
# Saved new best model to Models/Task_4/model_60.0%/fold_4.pth, with new best_val_loss=1.5842068360402033
# Saved new best model to Models/Task_4/model_60.0%/fold_4.pth, with new best_val_loss=1.2111157261408292
# Saved new best model to Models/Task_4/model_60.0%/fold_4.pth, with new best_val_loss=1.037701337154095
# Saved new best model to Models/Task_4/model_60.0%/fold_4.pth, with new best_val_loss=0.8997461094306065
# Saved new best model to Models/Task_4/model_60.0%/fold_4.pth, with new best_val_loss=0.8621506241651682
# Saved new best model to Models/Task_4/model_60.0%/fold_4.pth, with new best_val_loss=0.752706910096682
# Saved new best model to Models/Task_4/model_60.0%/fold_4.pth, with new best_val_loss=0.7281979890970084
# Saved new best model to Models/Task_4/model_60.0%/fold_4.pth, with new best_val_loss=0.6599283057909745
# Saved new best model to Models/Task_4/model_60.0%/fold_4.pth, with new best_val_loss=0.6217503091463676
# Saved new best model to Models/Task_4/model_60.0%/fold_4.pth, with new best_val_loss=0.5947635730871788
# Saved new best model to Models/Task_4/model_60.0%/fold_4.pth, with new best_val_loss=0.5390778734133794
# Saved new best model to Models/Task_4/model_60.0%/fold_4.pth, with new best_val_loss=0.4985235881346923
# Model dict saved in Models/Task_4/model_80.0%/model_dict.json
# Labels dict saved in Models/Task_4/model_80.0%/data_labels.json
#
#  ===================== Training Fold 0  =====================
#
# Saved new best model to Models/Task_4/model_80.0%/fold_0.pth, with new best_val_loss=1.4039482001600594
# Saved new best model to Models/Task_4/model_80.0%/fold_0.pth, with new best_val_loss=1.0412750898421497
# Saved new best model to Models/Task_4/model_80.0%/fold_0.pth, with new best_val_loss=0.8506204670873182
# Saved new best model to Models/Task_4/model_80.0%/fold_0.pth, with new best_val_loss=0.7812546775943932
# Saved new best model to Models/Task_4/model_80.0%/fold_0.pth, with new best_val_loss=0.7671282791543281
# Saved new best model to Models/Task_4/model_80.0%/fold_0.pth, with new best_val_loss=0.7158357874415386
# Saved new best model to Models/Task_4/model_80.0%/fold_0.pth, with new best_val_loss=0.7143996094150105
# Saved new best model to Models/Task_4/model_80.0%/fold_0.pth, with new best_val_loss=0.6303875024976402
# Saved new best model to Models/Task_4/model_80.0%/fold_0.pth, with new best_val_loss=0.6152937747966284
# Saved new best model to Models/Task_4/model_80.0%/fold_0.pth, with new best_val_loss=0.5522710941303736
# Saved new best model to Models/Task_4/model_80.0%/fold_0.pth, with new best_val_loss=0.5039237485877399
# Saved new best model to Models/Task_4/model_80.0%/fold_0.pth, with new best_val_loss=0.4506606682278644
# Saved new best model to Models/Task_4/model_80.0%/fold_0.pth, with new best_val_loss=0.4254147897249666
# Saved new best model to Models/Task_4/model_80.0%/fold_0.pth, with new best_val_loss=0.4065005532840545
# Saved new best model to Models/Task_4/model_80.0%/fold_0.pth, with new best_val_loss=0.3506545163691044
#
#  ===================== Training Fold 1  =====================
#
# Saved new best model to Models/Task_4/model_80.0%/fold_1.pth, with new best_val_loss=1.4721703255313567
# Saved new best model to Models/Task_4/model_80.0%/fold_1.pth, with new best_val_loss=1.1255133302732445
# Saved new best model to Models/Task_4/model_80.0%/fold_1.pth, with new best_val_loss=0.8805343046270567
# Saved new best model to Models/Task_4/model_80.0%/fold_1.pth, with new best_val_loss=0.78582803922138
# Saved new best model to Models/Task_4/model_80.0%/fold_1.pth, with new best_val_loss=0.714923027945661
# Saved new best model to Models/Task_4/model_80.0%/fold_1.pth, with new best_val_loss=0.6816819844574764
# Saved new best model to Models/Task_4/model_80.0%/fold_1.pth, with new best_val_loss=0.6144505949883625
# Saved new best model to Models/Task_4/model_80.0%/fold_1.pth, with new best_val_loss=0.5405898393913248
# Saved new best model to Models/Task_4/model_80.0%/fold_1.pth, with new best_val_loss=0.4989637807867993
# Saved new best model to Models/Task_4/model_80.0%/fold_1.pth, with new best_val_loss=0.462465352196803
# Saved new best model to Models/Task_4/model_80.0%/fold_1.pth, with new best_val_loss=0.3835092645523877
#
#  ===================== Training Fold 2  =====================
#
# Saved new best model to Models/Task_4/model_80.0%/fold_2.pth, with new best_val_loss=1.6318902476080532
# Saved new best model to Models/Task_4/model_80.0%/fold_2.pth, with new best_val_loss=1.0283839586137355
# Saved new best model to Models/Task_4/model_80.0%/fold_2.pth, with new best_val_loss=0.8225586263612769
# Saved new best model to Models/Task_4/model_80.0%/fold_2.pth, with new best_val_loss=0.7445376237918591
# Saved new best model to Models/Task_4/model_80.0%/fold_2.pth, with new best_val_loss=0.6181655325766268
# Saved new best model to Models/Task_4/model_80.0%/fold_2.pth, with new best_val_loss=0.6143785937764179
# Saved new best model to Models/Task_4/model_80.0%/fold_2.pth, with new best_val_loss=0.5600940179208229
# Saved new best model to Models/Task_4/model_80.0%/fold_2.pth, with new best_val_loss=0.5257490162534275
# Saved new best model to Models/Task_4/model_80.0%/fold_2.pth, with new best_val_loss=0.44838431734463263
# Saved new best model to Models/Task_4/model_80.0%/fold_2.pth, with new best_val_loss=0.4477103987987014
# Saved new best model to Models/Task_4/model_80.0%/fold_2.pth, with new best_val_loss=0.42339772919471236
# Saved new best model to Models/Task_4/model_80.0%/fold_2.pth, with new best_val_loss=0.38885833631301747
# Saved new best model to Models/Task_4/model_80.0%/fold_2.pth, with new best_val_loss=0.3720436556072071
# Saved new best model to Models/Task_4/model_80.0%/fold_2.pth, with new best_val_loss=0.3627071610983761
# Saved new best model to Models/Task_4/model_80.0%/fold_2.pth, with new best_val_loss=0.34283575274307154
#
#  ===================== Training Fold 3  =====================
#
# Saved new best model to Models/Task_4/model_80.0%/fold_3.pth, with new best_val_loss=1.488959243927879
# Saved new best model to Models/Task_4/model_80.0%/fold_3.pth, with new best_val_loss=0.9955292535924364
# Saved new best model to Models/Task_4/model_80.0%/fold_3.pth, with new best_val_loss=0.8287367841293072
# Saved new best model to Models/Task_4/model_80.0%/fold_3.pth, with new best_val_loss=0.7481476554925415
# Saved new best model to Models/Task_4/model_80.0%/fold_3.pth, with new best_val_loss=0.6714654015056019
# Saved new best model to Models/Task_4/model_80.0%/fold_3.pth, with new best_val_loss=0.6284923226326361
# Saved new best model to Models/Task_4/model_80.0%/fold_3.pth, with new best_val_loss=0.5511101580214226
# Saved new best model to Models/Task_4/model_80.0%/fold_3.pth, with new best_val_loss=0.5365454720697184
# Saved new best model to Models/Task_4/model_80.0%/fold_3.pth, with new best_val_loss=0.5047591836031141
# Saved new best model to Models/Task_4/model_80.0%/fold_3.pth, with new best_val_loss=0.4520978990985059
# Saved new best model to Models/Task_4/model_80.0%/fold_3.pth, with new best_val_loss=0.4395626785297846
# Saved new best model to Models/Task_4/model_80.0%/fold_3.pth, with new best_val_loss=0.431033739199241
# Saved new best model to Models/Task_4/model_80.0%/fold_3.pth, with new best_val_loss=0.40991280647529954
#
#  ===================== Training Fold 4  =====================
#
# Saved new best model to Models/Task_4/model_80.0%/fold_4.pth, with new best_val_loss=1.5401664574940999
# Saved new best model to Models/Task_4/model_80.0%/fold_4.pth, with new best_val_loss=1.086194639918448
# Saved new best model to Models/Task_4/model_80.0%/fold_4.pth, with new best_val_loss=0.8768319552657248
# Saved new best model to Models/Task_4/model_80.0%/fold_4.pth, with new best_val_loss=0.7150798268701838
# Saved new best model to Models/Task_4/model_80.0%/fold_4.pth, with new best_val_loss=0.577567431090892
# Saved new best model to Models/Task_4/model_80.0%/fold_4.pth, with new best_val_loss=0.57036936625667
# Saved new best model to Models/Task_4/model_80.0%/fold_4.pth, with new best_val_loss=0.5011977731496439
# Saved new best model to Models/Task_4/model_80.0%/fold_4.pth, with new best_val_loss=0.4601495846592147
# Saved new best model to Models/Task_4/model_80.0%/fold_4.pth, with new best_val_loss=0.43004271062626237
# Saved new best model to Models/Task_4/model_80.0%/fold_4.pth, with new best_val_loss=0.40398365875770303
# Saved new best model to Models/Task_4/model_80.0%/fold_4.pth, with new best_val_loss=0.38219476593979473
# Saved new best model to Models/Task_4/model_80.0%/fold_4.pth, with new best_val_loss=0.3655312065163563
# Saved new best model to Models/Task_4/model_80.0%/fold_4.pth, with new best_val_loss=0.3540377352686449

# %% [markdown]
# # Model Evaluation
# on Test set

# %%
import os
from utils8.Predictor import Predictor


acc_dict = {}
labels = [label for _, label in test_set]
for i in [20, 40, 60, 80]:
    path = os.path.join('Models', 'Task_4', f'model_{i}.0%')
    predictor = Predictor(path)
    pred = predictor.predict(test_set)

    acc = (pred == labels).sum() / len(labels)
    acc_dict[f'{i}%'] = acc

# Full dataset model
path = os.path.join('Models', 'model_2')
predictor = Predictor(path)
pred = predictor.predict(test_set)
acc = (pred == labels).sum() / len(labels)
acc_dict[f'100%'] = acc

acc_dict
# Out:
# {'20%': 0.8019939717134246,
#  '40%': 0.8516114073730582,
#  '60%': 0.9109668444238349,
#  '80%': 0.928124275446325,
#  '100%': 0.941340134477162}

# %%
import matplotlib.pyplot as plt

y = acc_dict.values()
x = acc_dict.keys()

plt.plot(x, y)
plt.title('Accuracy vs Percentage of train data used')
plt.xlabel('% of train data')
plt.ylabel('Accuracy')
plt.show()
