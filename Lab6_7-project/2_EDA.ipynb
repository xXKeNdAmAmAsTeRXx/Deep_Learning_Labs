# %%
import os
import pandas as pd
path = os.path.join('Data', 'trainVal.csv')
data = pd.read_csv(path)

X, y = data.drop('Air_Quality', axis=1), data['Air_Quality']

X
# Out:
#       Temperature  Humidity  PM2.5  PM10   NO2   SO2    CO  \
# 0            24.4      48.1   14.8  19.8  24.5   4.3  0.87
# 1            25.8      65.3   27.6  32.9  15.2   7.2  1.12
# 2            29.7      54.0    0.2   7.6  15.6   4.4  0.93
# 3            29.5      83.3    4.7  22.7  35.9  14.7  2.97
# 4            34.0      75.2   46.0  57.2  45.5  15.4  3.34
# ...           ...       ...    ...   ...   ...   ...   ...
# 3995         37.1      58.0   15.9  19.3  27.0  16.2  1.18
# 3996         35.1      71.0    2.6  16.5  19.0  10.3  1.61
# 3997         40.6      76.8   39.2  60.7  33.0  18.6  1.85
# 3998         36.8     100.2    4.9  14.2  40.2  32.5  3.02
# 3999         25.2      61.7   27.9  33.6  12.7   5.5  1.08
#
#       Proximity_to_Industrial_Areas  Population_Density
# 0                              12.0                 381
# 1                              10.4                 287
# 2                              10.8                 401
# 3                               5.2                 631
# 4                               6.3                 601
# ...                             ...                 ...
# 3995                            7.2                 403
# 3996                            7.3                 374
# 3997                            3.4                 686
# 3998                            2.9                 489
# 3999                           11.9                 300
#
# [4000 rows x 9 columns]
